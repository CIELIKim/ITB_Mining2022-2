# %% [markdown]
# # 분류 모델 구현

# %%
# !pip install mglearn
# Out:
# ...
#   Created wheel for mglearn: filename=mglearn-0.1.9-py2.py3-none-any.whl size=582637 sha256=2e039ec67d26f9fccaf3c9156ad323c4b5002b04b0b577c2bd7eb304cfb79c95
#   Stored in directory: c:\users\kcl02\appdata\local\pip\cache\wheels\df\30\8a\1e2c8f144c9d411b0688f628d496d2db8f61b6d14bcedaa1df
# Successfully built mglearn
# ...

# %%
# !pip install --upgrade joblib==1.1.0

# %%
import mglearn

# %%
import pandas as pd

# %%
DATA = pd.read_csv("health_data.csv")
df = pd.DataFrame(DATA)
df
# Out:
#       기준년도  가입자일련번호  시도코드 성별코드  연령대코드(5세단위)  신장(5Cm단위)  체중(5Kg 단위)   허리둘레  \
# 0     2020        1    36    M            9        165          60   72.1
# 1     2020        2    27    F           13        150          65   81.0
# 2     2020        3    11    F           12        155          55   70.0
# 3     2020        4    31    M           13        160          70   90.8
# 4     2020        5    41    F           12        155          50   75.2
# ...    ...      ...   ...  ...          ...        ...         ...    ...
# 9995  2020     9996    44    F           13        155          55   83.0
# 9996  2020     9997    43    F           11        160          55   77.5
# 9997  2020     9998    45    M           12        160          80   93.0
# 9998  2020     9999    27    F           15        155          55   78.0
# 9999  2020    10000    45    F           13        160          75  100.0
#
#       시력(좌)  시력(우)  ...  혈청크레아티닌  (혈청지오티)AST  (혈청지오티)ALT  감마지티피    흡연상태  음주여부  \
# ...

# %%
df.describe()
# Out:
#           기준년도      가입자일련번호          시도코드   연령대코드(5세단위)     신장(5Cm단위)  \
# count  10000.0  10000.00000  10000.000000  10000.000000  10000.000000
# mean    2020.0   5000.50000     34.100100     11.931400    160.983500
# std        0.0   2886.89568     12.394581      2.166048      9.211608
# min     2020.0      1.00000     11.000000      9.000000    130.000000
# 25%     2020.0   2500.75000     27.000000     10.000000    155.000000
# 50%     2020.0   5000.50000     41.000000     12.000000    160.000000
# 75%     2020.0   7500.25000     44.000000     13.000000    170.000000
# max     2020.0  10000.00000     49.000000     18.000000    195.000000
#
#          체중(5Kg 단위)          허리둘레         시력(좌)         시력(우)         청력(좌)  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      63.034500     82.366100      0.933750      0.936750      1.050500
# std       12.205294      9.561973      0.662057      0.641378      0.227936
# ...

# %%
df.head(10)
# Out:
#    기준년도  가입자일련번호  시도코드 성별코드  연령대코드(5세단위)  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  \
# 0  2020        1    36    M            9        165          60  72.1    1.2
# 1  2020        2    27    F           13        150          65  81.0    0.8
# 2  2020        3    11    F           12        155          55  70.0    0.6
# 3  2020        4    31    M           13        160          70  90.8    1.0
# 4  2020        5    41    F           12        155          50  75.2    1.5
# 5  2020        6    27    M            9        185          85  94.0    1.2
# 6  2020        7    44    M            9        165          80  93.0    0.8
# 7  2020        8    41    M           13        160          65  92.0    0.5
# 8  2020        9    41    F           17        150          50  82.0    0.4
# 9  2020       10    48    F           14        150          45  71.2    0.8
#
#    시력(우)  ...  혈청크레아티닌  (혈청지오티)AST  (혈청지오티)ALT  감마지티피  흡연상태  음주여부  구강검진수검여부  \
# ...

# %%
print(df.columns)
display(df.info())
# Out:
# Index(['기준년도', '가입자일련번호', '시도코드', '성별코드', '연령대코드(5세단위)', '신장(5Cm단위)',
#        '체중(5Kg 단위)', '허리둘레', '시력(좌)', '시력(우)', '청력(좌)', '청력(우)', '수축기혈압',
#        '이완기혈압', '식전혈당(공복혈당)', '총콜레스테롤', '트리글리세라이드', 'HDL콜레스테롤', 'LDL콜레스테롤',
#        '혈색소', '요단백', '혈청크레아티닌', '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피', '흡연상태',
#        '음주여부', '구강검진수검여부', '치아우식증유무', '치석', '데이터공개일자'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   기준년도         10000 non-null  int64
#  1   가입자일련번호      10000 non-null  int64
#  2   시도코드         10000 non-null  int64
#  3   성별코드         10000 non-null  object
#  4   연령대코드(5세단위)  10000 non-null  int64
#  5   신장(5Cm단위)    10000 non-null  int64
#  6   체중(5Kg 단위)   10000 non-null  int64
#  7   허리둘레         10000 non-null  float64
#  8   시력(좌)        10000 non-null  float64
# ...

# %%
DATA.isnull()
DATA.isnull().sum()
# Out:
# 기준년도              0
# 가입자일련번호           0
# 시도코드              0
# 성별코드              0
# 연령대코드(5세단위)       0
# 신장(5Cm단위)         0
# 체중(5Kg 단위)        0
# 허리둘레              0
# 시력(좌)             0
# 시력(우)             0
# 청력(좌)             0
# 청력(우)             0
# 수축기혈압            88
# 이완기혈압            88
# 식전혈당(공복혈당)       88
# 총콜레스테롤         5956
# 트리글리세라이드       5956
# HDL콜레스테롤       5956
# LDL콜레스테롤       6023
# 혈색소              88
# 요단백             139
# 혈청크레아티닌          88
# (혈청지오티)AST       88
# (혈청지오티)ALT       88
# 감마지티피            88
# 흡연상태              2
# 음주여부              1
# 구강검진수검여부          0
# 치아우식증유무        6749
# 치석             6749
# 데이터공개일자           0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.rc('font', family='NanumGothic') 
print(plt.rcParams['font.family'])
# Out:
# ['NanumGothic']

# %%
# %matplotlib inline

# %%
print(df['성별코드'].value_counts())

df['성별코드'].value_counts().plot.bar()
plt.ylabel('성별코드')
plt.title('성별분포')
plt.show()
# Out:
# M    5138
# F    4862
# Name: 성별코드, dtype: int64

# %%
mglearn.discrete_scatter(df['감마지티피'], df['허리둘레'], df['성별코드'])
plt.xlabel("감마지티피")
plt.ylabel("허리둘레")
plt.legend()
plt.show()

# %% [markdown]
# ## 의사결정나무

# %%
mglearn.plots.plot_tree_progressive()
# Out:
# C:\Users\kcl02\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:240: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\kcl02\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:203: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

X = df.iloc[:, 1:]  
y = df.iloc[:, 0]  

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state=100)

tree = DecisionTreeClassifier(random_state=0)  
tree.fit(X_train, y_train)
print("학습용 데이터 정확도: {:.3f}".format(tree.score(X_train, y_train)))
print("시험용 데이터 정확도: {:.3f}".format(tree.score(X_test, y_test)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27788/3367730858.py in <module>
#      12
#      13 tree = DecisionTreeClassifier(random_state=0)
# ---> 14 tree.fit(X_train, y_train)
#      15 print("학습용 데이터 정확도: {:.3f}".format(tree.score(X_train, y_train)))
#      16 print("시험용 데이터 정확도: {:.3f}".format(tree.score(X_test, y_test)))
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     901         """
#     902
# --> 903         super().fit(
#     904             X, y,
#     905             sample_weight=sample_weight,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     155             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
# ...

# %%
tree = DecisionTreeClassifier(max_depth=4, random_state=0)
tree.fit(X_train, y_train)

print("학습용 데이터 정확도: {:.3f}".format(tree.score(X_train, y_train)))
print("시험용 데이터 정확도: {:.3f}".format(tree.score(X_test, y_test)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27788/1020172249.py in <module>
#       1 tree = DecisionTreeClassifier(max_depth=4, random_state=0)
# ----> 2 tree.fit(X_train, y_train)
#       3
#       4 print("학습용 데이터 정확도: {:.3f}".format(tree.score(X_train, y_train)))
#       5 print("시험용 데이터 정확도: {:.3f}".format(tree.score(X_test, y_test)))
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     901         """
#     902
# --> 903         super().fit(
#     904             X, y,
#     905             sample_weight=sample_weight,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     155             check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
# ...

# %% [markdown]
# ## 분류 모델 : 혈청크레아티닌 &허리둘레

# %%
import sklearn.tree
from sklearn.tree import export_graphviz

# filled = True: 색상의 진하기로 클래스를 나타냄, impurity: 불순도 계산값 보여주기 옵션
export_graphviz(tree, out_file="tree.dot", class_names=[ "남성", "여성"],
                feature_names=df.columns[1:], impurity=False, filled=True)

with open("tree.dot") as f:
    dot_graph = f.read()

display(graphviz.Source(dot_graph))
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27788/2624761552.py in <module>
#       4
#       5 # filled = True: 색상의 진하기로 클래스를 나타냄, impurity: 불순도 계산값 보여주기 옵션
# ----> 6 export_graphviz(tree, out_file="tree.dot", class_names=[ "남성", "여성"],
#       7                 feature_names=df.columns[1:], impurity=False, filled=True)
#       8
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ...

# %% [markdown]
# ## 분류 모델 아이디어 - 음주여부 예측

# %% [markdown]
# ### 방법1. 의사결정나무 모델

# %% [markdown]
# #### -성별, 나이, 감마지티피 정보를 이용. 감마지티피의 경우 신생아 약 100 IU/L, 성인 여성은 8~35 IU/L, 남성 11~63 IU/L 이므로 나이대 별로 수치형을 범주형으로 바꾸어 기준에 따라 정상/비정상으로 범주를 나누어 파생변수를 생성한다. 그리고 이를 의사결정나무 모델을 사용해서 분류한다.

# %% [markdown]
# ### 방법2. 앙상블 모델

# %% [markdown]
# #### - 앞의 기본적인 의사결정나무 모델과 거의 유사하나 모델링에서 피할 수 없는 과적합 문제를 해결하기 위해 랜덤포레스트와 그래디언트 부스팅 또한 사용하여 예측해봄. 독립/종속 변수는 똑같이 설정

# %% [markdown]
# ### 평가: 교차검증

# %% [markdown]
# #### - 특정 데이터에만 과적합되는 모델을 만들지 않으면서 모든 데이터에 일반화가 잘 되었는지 평가하기 위해 교차검증을 이용한다. 이후 k 번 수행한 교차검증의 평균값을 이용한다.

# %% [markdown]
# ### 예상 인사이트

# %% [markdown]
# #### -음주여부를 성별, 나이 그리고 감마지티피 변수를 이용해 분석하는 것은 감마지티피가 간질환 발생과의 연관성을 가지고 있고 간질환은 주로 음주에 의해 일어나는 경우가 크기에 이들 변수와의 연관성을 생각해 위 아이디어를 도출해내보았다.
# #### 특히 변수 중 감마지티피가 성별 및 나이에 따라 변화하는 특성을 지니고 있기 때문에 분류 과정에서 위 변수가 모델링에 어떻게 작용할 지를 보는 것이 주목할 만 한 부분이라는 생각이 든다.
